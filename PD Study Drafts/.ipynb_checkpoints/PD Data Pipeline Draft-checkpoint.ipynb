# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#path = r'C:\Users\adai\Documents\PD Study Data\updated_demo_pd_01\updated_demo_pd\01'
path = r'C:\Users\adai\Downloads\pd_study_v2_0_1004\PD Study v2.0\1004'

files = os.listdir(path)

for entries in files:
    if entries == 'annotations.csv':
        print(os.path.join(path, entries))
        df = pd.read_csv(os.path.join(path, entries))

# removes unnecessary data columns
del df['Timestamp (ms)']
del df['AnnotationId']
del df['AuthorId']

df['Start Timestamp (ms)'] = pd.to_datetime(df['Start Timestamp (ms)'], unit='ms', utc=True)
df['Stop Timestamp (ms)'] = pd.to_datetime(df['Stop Timestamp (ms)'], unit='ms', utc=True)

sorter = df.EventType.unique()
sorterIndex = dict(zip(sorter,range(len(sorter))))

df['EventType_Rank'] = df['EventType'].map(sorterIndex)

testDay = df[(df.EventType == 'Testing Day') & (df.Value != 'NaN')].dropna(how='any').Value
print(testDay)

df = df[((df.EventType != 'Testing Day') & (df.Value != 'NaN'))]
df.sort_values(['EventType_Rank', 'Start Timestamp (ms)'], axis=0)
# Out:
# C:\Users\adai\Downloads\pd_study_v2_0_1004\PD Study v2.0\1004\annotations.csv
# 2    DAY 1
# Name: Value, dtype: object
#                               EventType    Start Timestamp (ms)  \
# 0                Heart Rate Variability 2017-07-07 13:15:33.880
# 104              Heart Rate Variability 2017-07-07 16:35:53.043
# 3          MDS-UPDRS #1: Finger Tapping 2017-07-07 13:32:44.865
# 41         MDS-UPDRS #1: Finger Tapping 2017-07-07 15:00:07.797
# 4          MDS-UPDRS #2: Hand Movements 2017-07-07 13:33:01.669
# 42         MDS-UPDRS #2: Hand Movements 2017-07-07 15:00:25.635
# 5    MDS-UPDRS #3: Pronation-Supination 2017-07-07 13:33:15.837
# 43   MDS-UPDRS #3: Pronation-Supination 2017-07-07 15:00:42.179
# 6             MDS-UPDRS #4: Toe Tapping 2017-07-07 13:33:28.186
# 44            MDS-UPDRS #4: Toe Tapping 2017-07-07 15:00:55.130
# 7             MDS-UPDRS #5: Leg Agility 2017-07-07 13:33:43.006
# 45            MDS-UPDRS #5: Leg Agility 2017-07-07 15:01:08.793
# 8      MDS-UPDRS #6: Arising from Chair 2017-07-07 13:33:53.974
# 46     MDS-UPDRS #6: Arising from Chair 2017-07-07 15:01:20.254
# 9                    MDS-UPDRS #7: Gait 2017-07-07 13:34:05.293
# 47                   MDS-UPDRS #7: Gait 2017-07-07 15:01:29.446
# 10     MDS-UPDRS #8: Postural Stability 2017-07-07 13:34:29.293
# 48     MDS-UPDRS #8: Postural Stability 2017-07-07 15:01:40.797
# 11   MDS-UPDRS #9: Postural Hand Tremor 2017-07-07 13:35:05.427
# 49   MDS-UPDRS #9: Postural Hand Tremor 2017-07-07 15:02:02.910
# 12           MDS-UPDRS #11: Rest Tremor 2017-07-07 13:35:30.810
# 13                   Motor #1: Standing 2017-07-07 13:39:05.605
# 43  2017-07-07 15:00:50.002   NaN               4
# 6   2017-07-07 13:33:39.320   NaN               5
# 44  2017-07-07 15:01:05.252   NaN               5
# 7   2017-07-07 13:33:50.233   NaN               6
# 45  2017-07-07 15:01:16.634   NaN               6
# 8   2017-07-07 13:34:00.149   NaN               7
# 46  2017-07-07 15:01:24.915   NaN               7
# 9   2017-07-07 13:34:18.738   NaN               8
# 47  2017-07-07 15:01:37.947   NaN               8
# 10  2017-07-07 13:34:37.034   NaN               9
# 48  2017-07-07 15:01:48.153   NaN               9
# 11  2017-07-07 13:35:15.713   NaN              10
# 49  2017-07-07 15:02:09.431   NaN              10
# 12  2017-07-07 13:35:39.710   NaN              11
# 13  2017-07-07 13:39:37.591   NaN              12
# 27  2017-07-07 14:25:15.969   NaN              12
# 51  2017-07-07 15:05:08.891   NaN              12
# 64  2017-07-07 15:36:21.997   NaN              12
# 78  2017-07-07 16:02:29.912   NaN              12
# 91  2017-07-07 16:27:05.632   NaN              12
# 14  2017-07-07 13:40:36.513   NaN              13
# 28  2017-07-07 14:26:03.141   NaN              13
# 52  2017-07-07 15:05:52.424   NaN              13
# ..                      ...   ...             ...
# 36  2017-07-07 14:32:51.483   NaN              20
# 59  2017-07-07 15:12:04.599   NaN              20
# 73  2017-07-07 15:44:08.237   NaN              20
# 86  2017-07-07 16:08:44.299   NaN              20
# 99  2017-07-07 16:33:19.023   NaN              20
# 23  2017-07-07 13:51:09.745   NaN              21
# 37  2017-07-07 14:33:29.736   NaN              21
# 60  2017-07-07 15:12:33.880   NaN              21
# 74  2017-07-07 15:44:41.872   NaN              21
# 87  2017-07-07 16:09:15.128   NaN              21
# 100 2017-07-07 16:33:49.522   NaN              21
# 24  2017-07-07 13:52:33.323   NaN              22
# 38  2017-07-07 14:34:09.305   NaN              22
# 61  2017-07-07 15:13:24.361   NaN              22
# 75  2017-07-07 15:45:25.547   NaN              22
# 88  2017-07-07 16:09:58.748   NaN              22
# 101 2017-07-07 16:34:28.406   NaN              22
# 25  2017-07-07 13:53:45.441   NaN              23
# 39  2017-07-07 14:34:39.994   NaN              23
# 62  2017-07-07 15:13:48.523   NaN              23
# 76  2017-07-07 15:45:49.171   NaN              23
# 89  2017-07-07 16:10:28.944   NaN              23
# 102 2017-07-07 16:34:55.818   NaN              23
# 26  2017-07-07 13:54:33.423   NaN              24
# 40  2017-07-07 14:35:26.741   NaN              24
# 63  2017-07-07 15:14:33.356   NaN              24
# 77  2017-07-07 15:46:26.465   NaN              24
# 90  2017-07-07 16:11:06.780   NaN              24
# 103 2017-07-07 16:35:40.273   NaN              24
# 50  2017-07-07 15:02:22.242   NaN              25
#
# [103 rows x 5 columns]

# %%
def sort_sensor_data(path):
    files = os.listdir(path)
    
    for entries in files:
        if entries == 'annotations.csv':

# %%
def sort_events(df, events):
    for labels in events:
        df.groupby('EventType').get_group(labels)
