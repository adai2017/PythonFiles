# %%
import os
import math
import requests
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly
import plotly.plotly as py
import plotly.figure_factory as ff

if int(os.environ.get("MODERN_PANDAS_EPUB", 0)):
    import prep

params = (
    ('Table_ID', '236'),
    ('Has_Group', '3'),
    ('Is_Zipped', '0'),
)

# %%
df = pd.read_csv("PD_workbook_mk9_test.csv")
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 8 columns):
# Participant                      15 non-null object
# Current Status                   14 non-null float64
# Next Scheduled Visit             13 non-null object
# Added to PD study app [1]        14 non-null object
# Completed Day 1 Testing [2]      9 non-null object
# Completed Day 2 Testing [3]      6 non-null object
# Data ready for processing [4]    4 non-null object
# Data processed [5]               2 non-null object
# dtypes: float64(1), object(7)
# memory usage: 1.0+ KB
#   Participant  Current Status Next Scheduled Visit Added to PD study app [1]  \
# 0        1004             2.0                  NaN                  7/5/2017
# 1        1016             1.0            7/13/2017                  7/5/2017
# 2        1018             1.0            7/14/2017                  7/5/2017
# 3        1020             1.0            7/20/2017                  7/5/2017
# ...

# %%
participant = df.groupby('Participant').first()
one = participant.loc[['1004','1016','1018','1020','1024','1029','1034','1039','1044','1049','1054','1059','1064','1069'],['Current Status']]
two = participant.loc[['1004','1016','1018','1020','1024','1029','1034','1039','1044','1049','1054','1059','1064','1069'],['Next Scheduled Visit']]
three=participant.loc[['1004','1016','1018','1020','1024','1029','1034','1039','1044','1049','1054','1059','1064','1069'],['Added to PD study app [1]']]
four= participant.loc[['1004','1016','1018','1020','1024','1029','1034','1039','1044','1049','1054','1059','1064','1069'],['Completed Day 1 Testing [2]']]
five= participant.loc[['1004','1016','1018','1020','1024','1029','1034','1039','1044','1049','1054','1059','1064','1069'],['Completed Day 2 Testing [3]']]
six = participant.loc[['1004','1016','1018','1020','1024','1029','1034','1039','1044','1049','1054','1059','1064','1069'],['Data ready for processing [4]']]
seven=participant.loc[['1004','1016','1018','1020','1024','1029','1034','1039','1044','1049','1054','1059','1064','1069'],['Data processed [5]']]

print (one,'\n','-'*31,'\n',two,'\n','-'*36,'\n',three,'\n','-'*38,'\n',four,'\n','-'*39,'\n',five,'\n','-'*41,'\n',six,'\n','-'*30,'\n',seven,'\n')
# Out:
#              Current Status
# Participant
# 1004                    2.0
# 1016                    1.0
# 1018                    1.0
# 1020                    1.0
# 1024                    1.0
# 1029                    1.0
# 1034                    2.0
# 1039                    2.0
# 1044                    3.0
# 1049                    3.0
# 1054                    4.0
# 1059                    4.0
# 1064                    5.0
# 1069                    5.0
#  -------------------------------
#              Next Scheduled Visit
# Participant
# 1004                         NaN
# 1016                   7/13/2017
# 1018                   7/14/2017
# 1020                   7/20/2017
# 1024                   7/19/2017
# 1029                   7/27/2017
# 1034                    8/4/2017
# 1039                   8/12/2017
# 1044                   8/20/2017
# 1049                   8/28/2017
# 1054                    9/5/2017
# 1059                   9/13/2017
# ...

# %%
Status0 = []
Status1 = []
Status2 = []
Status3 = []
Status4 = []
Status5 = []
 
for xx in range(15):
    if (math.isnan(df['Current Status'][xx])):
        Status0.append(str(df['Participant'][xx]))
    elif ((str(int(df['Current Status'][xx]))) == '1'):
        Status1.append(str(df['Participant'][xx]))
    elif ((str(int(df['Current Status'][xx]))) == '2'):
        Status2.append(str(df['Participant'][xx]))
    elif ((str(int(df['Current Status'][xx]))) == '3'):
        Status3.append(str(df['Participant'][xx]))
    elif ((str(int(df['Current Status'][xx]))) == '4'):
        Status4.append(str(df['Participant'][xx]))
    elif ((str(int(df['Current Status'][xx]))) == '5'):
        Status5.append(str(df['Participant'][xx]))

print (" Participants in stage 1 - Added to study app\n",Status1,'\n\n',"Participants in stage 2 - Completed day 1 testing:\n",Status2,'\n\n',"Participants in stage 3 - Completed day 2 testing:\n",Status3,'\n\n',"Participants in stage 4 - Data ready for processing:\n",Status4,'\n\n',"Participants in stage 5 - Data processed:\n",Status5)
# Out:
#  Participants in stage 1 - Added to study app
#  ['1016', '1018', '1020', '1024', '1029']
#
#  Participants in stage 2 - Completed day 1 testing:
#  ['1004', '1034', '1039']
#
#  Participants in stage 3 - Completed day 2 testing:
#  ['1044', '1049']
#
#  Participants in stage 4 - Data ready for processing:
#  ['1054', '1059']
#
#  Participants in stage 5 - Data processed:
#  ['1064', '1069']
