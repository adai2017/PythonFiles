# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['figure.figsize'] = (15, 5)
plt.style.use('ggplot')

# %%
Location = r'C:\Users\adai\Documents\GitHub\pandas-cookbook\data\weather_2012.csv'
weather_2012_final = pd.read_csv(Location, index_col='Date/Time')
weather_2012_final['Temp (C)'].plot(figsize=(15,6))

# %%
data_location = r'C:\Users\adai\Documents\GitHub\PythonFiles\'

# %%
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-4-5cb547a590b4> in <module>()
#       1 url = url_template.format(month=3, year=2012)
# ----> 2 weather_mar2012 = pd.read_csv(url, skiprows=16, index_col='Date/Time', parse_dates=True, encoding='latin1')
#
# ...
